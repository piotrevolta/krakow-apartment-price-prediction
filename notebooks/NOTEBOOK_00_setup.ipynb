# %% [markdown]
# <a href="https://colab.research.google.com/github/piotrevolta/krakow-apartment-price-prediction/blob/main/notebooks/NOTEBOOK_00_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print(sys.version)
print(pd.__version__)

sns.set(style="whitegrid")
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# 2.2.2
