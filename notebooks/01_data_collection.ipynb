# %% [markdown]
# <a href="https://colab.research.google.com/github/piotrevolta/krakow-apartment-price-prediction/blob/main/notebooks/01_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Collection – Apartment Prices in Kraków
#
# ## Goal
# The goal of this notebook is to collect raw apartment listing data
# that will be used in further stages of the data science project.
#
# At this stage:
# - no data cleaning is performed
# - no analysis is done
# - data is saved in raw form

# %% [markdown]
# ## Data source
# Planned data source:
# - Otodom.pl (public real estate listings)
#
# Important notes:
# - Data collection is for educational purposes only
# - No personal data will be collected
# - Scraping logic will be implemented in a separate module

# %% [markdown]
# ## Data collection logic
#
# Scraping logic will be implemented in:
# - src/scraping.py
#
# This notebook will only call that logic and save results to:
# - data/raw/

# %%
import pandas as pd

# %%
#Repository creation on Colab based on GitHub

from pathlib import Path

# %cd /content

REPO_URL = "https://github.com/piotrevolta/krakow-apartment-price-prediction.git"
REPO_DIR = Path("/content/krakow-apartment-price-prediction")

if not REPO_DIR.exists():
    # !git clone {REPO_URL}

# %cd /content/krakow-apartment-price-prediction
# !pwd
# !ls
# Out:
# /content
# Cloning into 'krakow-apartment-price-prediction'...
# remote: Enumerating objects: 180, done.
# remote: Counting objects: 100% (180/180), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 180 (delta 76), reused 75 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (180/180), 69.87 KiB | 3.68 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# /content/krakow-apartment-price-prediction
# /content/krakow-apartment-price-prediction
#  data			   notebooks   reports		  src
# 'Fields description.txt'   README.md   requirements.txt

# %%
#repository synchronization GitHub -> Colab
#!git pull --rebase

import importlib
import src.scraping as sc

importlib.reload(sc)
from src.scraping import collect_raw_listings, enrich_with_details

print("Imported from:", sc.__file__)
# Out:
# Imported from: /content/krakow-apartment-price-prediction/src/scraping.py

# %%
df_raw = collect_raw_listings(max_pages=1)
df_enriched = enrich_with_details(df_raw, max_details=30, sleep_s=1.0)

print("df_raw shape:", df_raw.shape)
print("df_enriched shape:", df_enriched.shape)

out_dir = Path("data/raw")
out_dir.mkdir(parents=True, exist_ok=True)

out_path = out_dir / "apartments_krakow_enriched.csv"
df_enriched.to_csv(out_path, index=False)

print("Saved:", out_path.resolve())
print("Files in data/raw:", [p.name for p in out_dir.glob("*")])
# Out:
# df_raw shape: (17, 9)
# df_enriched shape: (17, 19)
# Saved: /content/krakow-apartment-price-prediction/data/raw/apartments_krakow_enriched.csv
# Files in data/raw: ['.gitkeep', 'apartments_krakow_enriched.csv']

# %%
df_enriched.head(50)
# Out:
#                                           listing_url  \
# 0   https://www.otodom.pl/pl/oferta/sprzedam-2-pok...
# 1   https://www.otodom.pl/pl/oferta/sprzedam-3-pok...
# 2   https://www.otodom.pl/pl/oferta/sprzedam-miesz...
# 3   https://www.otodom.pl/pl/oferta/sprzedam-2-pok...
# 4   https://www.otodom.pl/pl/oferta/urocze-mieszka...
# 5   https://www.otodom.pl/pl/oferta/2-pokoje-balko...
# 6   https://www.otodom.pl/pl/oferta/sprzedam-miesz...
# 7   https://www.otodom.pl/pl/oferta/swietna-lokali...
# 8   https://www.otodom.pl/pl/oferta/doskonale-skom...
# 9   https://www.otodom.pl/pl/oferta/2-pokojowe-mie...
# 10  https://www.otodom.pl/pl/oferta/kozlowek-2-pok...
# 11  https://www.otodom.pl/pl/oferta/2-pokoje-osobn...
# 12  https://www.otodom.pl/pl/oferta/trzypokojowe-m...
# 13  https://www.otodom.pl/pl/oferta/przestronna-ka...
# 14  https://www.otodom.pl/pl/oferta/mieszkanie-w-d...
# 15  https://www.otodom.pl/pl/oferta/pychowice-dwup...
# 16  https://www.otodom.pl/hpr/pl/oferta/sprzedam-2...
#
#                                          address_text  \
# 0   Jana Kantego Federowicza, Skotniki, Dębniki, K...
# 1   Jana Kantego Federowicza, Skotniki, Dębniki, K...
# 2   Jana Kantego Federowicza, Skotniki, Dębniki, K...
# 3   Jana Kantego Federowicza, Skotniki, Dębniki, K...
# 4   ul. Jonatana Warszauera, Kazimierz, Stare Mias...
# 5              Dąbie, Grzegórzki, Kraków, małopolskie
# 6   ul. Gnieźnieńska, Azory, Prądnik Biały, Kraków...
# 7   ul. Żwirki i Wigury, Rakowice, Prądnik Czerwon...
# 8   os. Na Lotnisku, Nowe Bieńczyce, Bieńczyce, Kr...
# 9   ul. Piasta Kołodzieja, Mistrzejowice Północ, M...
# 10  ul. Na Kozłówce, Kozłówka, Bieżanów-Prokocim, ...
# 11          Azory, Prądnik Biały, Kraków, małopolskie
# 12          Bronowice, Bronowice, Kraków, małopolskie
# 13             Łobzów, Krowodrza, Kraków, małopolskie
# 14          Bronowice, Bronowice, Kraków, małopolskie
# 15  ul. Sodowa, Pychowice, Dębniki, Kraków, małopo...
# 16  Jana Kantego Federowicza, Skotniki, Dębniki, K...
#
#               address_street   address_subdistrict   address_district  \
# 0   Jana Kantego Federowicza              Skotniki            Dębniki
# 1   Jana Kantego Federowicza              Skotniki            Dębniki
# 2   Jana Kantego Federowicza              Skotniki            Dębniki
# 3   Jana Kantego Federowicza              Skotniki            Dębniki
# 4    ul. Jonatana Warszauera             Kazimierz       Stare Miasto
# 5                       None                 Dąbie         Grzegórzki
# 6           ul. Gnieźnieńska                 Azory      Prądnik Biały
# 7        ul. Żwirki i Wigury              Rakowice   Prądnik Czerwony
# 8            os. Na Lotnisku        Nowe Bieńczyce          Bieńczyce
# 9      ul. Piasta Kołodzieja  Mistrzejowice Północ      Mistrzejowice
# 10           ul. Na Kozłówce              Kozłówka  Bieżanów-Prokocim
# 11                      None                 Azory      Prądnik Biały
# 12                      None             Bronowice          Bronowice
# 13                      None                Łobzów          Krowodrza
# 14                      None             Bronowice          Bronowice
# 15                ul. Sodowa             Pychowice            Dębniki
# 16  Jana Kantego Federowicza              Skotniki            Dębniki
#
#    address_city address_voivodeship      price_text price_per_m2_text  \
# 0        Kraków         małopolskie      539 000 zł      16 152 zł/m²
# 1        Kraków         małopolskie      786 000 zł      14 354 zł/m²
# 2        Kraków         małopolskie      810 000 zł      14 816 zł/m²
# 3        Kraków         małopolskie      548 000 zł      16 353 zł/m²
# 4        Kraków         małopolskie      789 000 zł      19 627 zł/m²
# 5        Kraków         małopolskie      735 000 zł      19 865 zł/m²
# 6        Kraków         małopolskie      425 000 zł      17 708 zł/m²
# 7        Kraków         małopolskie      415 000 zł      13 108 zł/m²
# 8        Kraków         małopolskie      435 000 zł      11 785 zł/m²
# 9        Kraków         małopolskie  Zapytaj o cenę              None
# 10       Kraków         małopolskie      469 000 zł      12 811 zł/m²
# 11       Kraków         małopolskie      725 000 zł      13 942 zł/m²
# 12       Kraków         małopolskie      915 000 zł      12 365 zł/m²
# 13       Kraków         małopolskie      518 000 zł      18 500 zł/m²
# 14       Kraków         małopolskie      499 000 zł      12 385 zł/m²
# 15       Kraków         małopolskie      969 000 zł      14 463 zł/m²
# 16       Kraków         małopolskie      539 000 zł      16 152 zł/m²
#
#    area_text floor_text rooms_count_text  has_garden  has_balcony  \
# 0   33.37 m²        1/4                2           0            0
# 1   54.76 m²   parter/4                3           0            0
# 2   54.67 m²        1/4                3           0            0
# 3   33.51 m²   parter/4                2           0            0
# 4    40.2 m²          3                1           0            0
# 5      37 m²        4/6                2           0            1
# 6      24 m²       3/10                1           0            0
# 7   31.66 m²   parter/2                2           0            0
# 8   36.91 m²        2/4                2           0            0
# 9   37.25 m²        5/8                2           0            1
# 10  36.61 m²        3/4                2           0            0
# 11     52 m²        5/6                2           0            1
# 12     74 m²          7                3           0            0
# 13     28 m²        1/3                1           0            0
# 14  40.29 m²   parter/3                2           1            0
# 15     67 m²          1                3           0            1
# 16  33.37 m²        1/4                2           0            0
#
#     has_parking  has_basement year_built_text  has_elevator  has_storage
# 0             0             0            2024             0            0
# 1             0             0            2024             0            0
# 2             0             0            2024             0            0
# 3             0             0            2024             0            0
# 4             0             1            None             0            0
# 5             1             0            2023             1            0
# 6             0             1            1970             1            0
# 7             0             0            1910             0            0
# 8             0             1            1970             0            0
# 9             1             0            2025             1            0
# 10            0             1            1970             0            0
# 11            1             1            2010             1            1
# 12            0             0            1998             0            0
# 13            0             0            1960             0            0
# 14            0             0            1960             0            0
# 15            1             0            2023             0            0
# 16            0             0            2024             0            0
