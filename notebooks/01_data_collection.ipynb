# %% [markdown]
# # Data Collection – Apartment Prices in Kraków
#
# ## Goal
# The goal of this notebook is to collect raw apartment listing data
# that will be used in further stages of the data science project.
#
# At this stage:
# - no data cleaning is performed
# - no analysis is done
# - data is saved in raw form

# %% [markdown]
# ## Data source
# Planned data source:
# - Otodom.pl (public real estate listings)
#
# Important notes:
# - Data collection is for educational purposes only
# - No personal data will be collected
# - Scraping logic will be implemented in a separate module

# %% [markdown]
# ## Data collection logic
#
# Scraping logic will be implemented in:
# - src/scraping.py
#
# This notebook will only call that logic and save results to:
# - data/raw/

# %%
import pandas as pd

# %%
#Repository creation on Colab based on GitHub

from pathlib import Path

# %cd /content

REPO_URL = "https://github.com/piotrevolta/krakow-apartment-price-prediction.git"
REPO_DIR = Path("/content/krakow-apartment-price-prediction")

if not REPO_DIR.exists():
    # !git clone {REPO_URL}

# %cd /content/krakow-apartment-price-prediction
# !pwd
# !ls
# Out:
# /content
# /content/krakow-apartment-price-prediction
# /content/krakow-apartment-price-prediction
#  data			   notebooks   reports		  src
# 'Fields description.txt'   README.md   requirements.txt

# %%
#repository synchronization GitHub -> Colab
#!git pull --rebase

import importlib
import src.scraping as sc

importlib.reload(sc)
from src.scraping import collect_raw_listings, enrich_with_details

print("Imported from:", sc.__file__)
# Out:
# Imported from: /content/krakow-apartment-price-prediction/src/scraping.py

# %%
df_raw = collect_raw_listings(max_pages=1)
df_enriched = enrich_with_details(df_raw, max_details=30, sleep_s=1.0)

print("df_raw shape:", df_raw.shape)
print("df_enriched shape:", df_enriched.shape)

out_dir = Path("data/raw")
out_dir.mkdir(parents=True, exist_ok=True)

out_path = out_dir / "apartments_krakow_enriched.csv"
df_enriched.to_csv(out_path, index=False)

print("Saved:", out_path.resolve())
print("Files in data/raw:", [p.name for p in out_dir.glob("*")])
# Out:
# df_raw shape: (21, 9)
# df_enriched shape: (21, 10)
# Saved: /content/krakow-apartment-price-prediction/data/raw/apartments_krakow_enriched.csv
# Files in data/raw: ['apartments_krakow_raw.csv', '.gitkeep', 'apartments_krakow_enriched.csv']

# %%
df_enriched.head(50)
# Out:
#                                           listing_url  \
# 0   https://www.otodom.pl/pl/oferta/bezposrednio-3...
# 1   https://www.otodom.pl/pl/oferta/3-pokojowe-mie...
# 2   https://www.otodom.pl/pl/oferta/jasne-3niezale...
# 3   https://www.otodom.pl/pl/oferta/3-pokojowe-mie...
# 4   https://www.otodom.pl/pl/oferta/2-pokoje-remon...
# 5   https://www.otodom.pl/pl/oferta/ekskluzywna-ni...
# 6   https://www.otodom.pl/pl/oferta/wola-justowska...
# 7   https://www.otodom.pl/pl/oferta/dwupoziomowy-a...
# 8   https://www.otodom.pl/pl/oferta/unikatowy-tara...
# 9   https://www.otodom.pl/pl/oferta/mieszkanie-2-p...
# 10  https://www.otodom.pl/pl/oferta/4-pokojowe-mie...
# 11  https://www.otodom.pl/pl/oferta/pilna-sprzedaz...
# 12  https://www.otodom.pl/pl/oferta/2-pokojowe-spr...
# 13  https://www.otodom.pl/pl/oferta/gotowiec-inwes...
# 14  https://www.otodom.pl/pl/oferta/ladne-2-pokojo...
# 15  https://www.otodom.pl/pl/oferta/pradnik-czerwo...
# 16  https://www.otodom.pl/pl/oferta/plaszow-mysliw...
# 17  https://www.otodom.pl/pl/oferta/krowodrza-ulic...
# 18  https://www.otodom.pl/pl/oferta/mieszkanie-do-...
# 19  https://www.otodom.pl/pl/oferta/5-pokojowe-mie...
# 20  https://www.otodom.pl/hpr/pl/oferta/bezposredn...
#
#                                          address_text  \
# 0   os. Na Lotnisku, Nowe Bieńczyce, Bieńczyce, Kr...
# 1   ul. Josepha Conrada, Azory Zachód, Prądnik Bia...
# 2   ul. Kobierzyńska, Ruczaj, Dębniki, Kraków, mał...
# 3   ul. Dajwór, Kazimierz, Stare Miasto, Kraków, m...
# 4     Stare Bieńczyce, Bieńczyce, Kraków, małopolskie
# 5   ul. Piaskowa, Bronowice Wielkie, Prądnik Biały...
# 6   ul. Królowej Jadwigi, Wola Justowska, Zwierzyn...
# 7   ul. Władysława Łokietka, Tonie, Prądnik Biały,...
# 8   ul. Górka Narodowa, Górka Narodowa, Prądnik Bi...
# 9   os. Dywizjonu 303 303, Czyżyny Lotnisko, Czyży...
# 10  Federowicza, Skotniki, Dębniki, Kraków, małopo...
# 11  ul. bp. Jana Prandoty, Przedmieście Warszawski...
# 12  ul. Rakowicka, Osiedle Oficerskie, Grzegórzki,...
# 13  ul. Siewna, Prądnik Biały Wschód, Prądnik Biał...
# 14  ul. Złocieniowa, Złocień, Bieżanów-Prokocim, K...
# 15  ul. abp. Zygmunta Szczęsnego Felińskiego, Prąd...
# 16  ul. Myśliwska, Płaszów, Podgórze, Kraków, mało...
# 17  ul. Marii Jaremy, Nowa Wieś, Krowodrza, Kraków...
# 18  ul. Rzepichy, Zakamycze, Zwierzyniec, Kraków, ...
# 19  ul. Łagiewnicka, Bonarka, Podgórze, Kraków, ma...
# 20  os. Na Lotnisku, Nowe Bieńczyce, Bieńczyce, Kr...
#
#                               address_street       address_subdistrict  \
# 0                            os. Na Lotnisku            Nowe Bieńczyce
# 1                        ul. Josepha Conrada              Azory Zachód
# 2                           ul. Kobierzyńska                    Ruczaj
# 3                                 ul. Dajwór                 Kazimierz
# 4                                       None           Stare Bieńczyce
# 5                               ul. Piaskowa         Bronowice Wielkie
# 6                       ul. Królowej Jadwigi            Wola Justowska
# 7                    ul. Władysława Łokietka                     Tonie
# 8                         ul. Górka Narodowa            Górka Narodowa
# 9                      os. Dywizjonu 303 303          Czyżyny Lotnisko
# 10                               Federowicza                  Skotniki
# 11                     ul. bp. Jana Prandoty  Przedmieście Warszawskie
# 12                             ul. Rakowicka        Osiedle Oficerskie
# 13                                ul. Siewna      Prądnik Biały Wschód
# 14                           ul. Złocieniowa                   Złocień
# 15  ul. abp. Zygmunta Szczęsnego Felińskiego          Prądnik Czerwony
# 16                             ul. Myśliwska                   Płaszów
# 17                          ul. Marii Jaremy                 Nowa Wieś
# 18                              ul. Rzepichy                 Zakamycze
# 19                           ul. Łagiewnicka                   Bonarka
# 20                           os. Na Lotnisku            Nowe Bieńczyce
#
#      address_district address_city address_voivodeship    price_text  \
# 0           Bieńczyce       Kraków         małopolskie    599 000 zł
# 1       Prądnik Biały       Kraków         małopolskie    901 511 zł
# 2             Dębniki       Kraków         małopolskie    795 000 zł
# 3        Stare Miasto       Kraków         małopolskie  2 875 537 zł
# 4           Bieńczyce       Kraków         małopolskie    399 000 zł
# 5       Prądnik Biały       Kraków         małopolskie  1 349 000 zł
# 6         Zwierzyniec       Kraków         małopolskie    725 000 zł
# 7       Prądnik Biały       Kraków         małopolskie  1 600 000 zł
# 8       Prądnik Biały       Kraków         małopolskie    765 000 zł
# 9             Czyżyny       Kraków         małopolskie    739 000 zł
# 10            Dębniki       Kraków         małopolskie  1 008 320 zł
# 11       Stare Miasto       Kraków         małopolskie    756 666 zł
# 12         Grzegórzki       Kraków         małopolskie    359 800 zł
# 13      Prądnik Biały       Kraków         małopolskie  1 200 000 zł
# 14  Bieżanów-Prokocim       Kraków         małopolskie    659 000 zł
# 15   Prądnik Czerwony       Kraków         małopolskie    669 000 zł
# 16           Podgórze       Kraków         małopolskie  1 390 000 zł
# 17          Krowodrza       Kraków         małopolskie    549 000 zł
# 18        Zwierzyniec       Kraków         małopolskie  1 499 000 zł
# 19           Podgórze       Kraków         małopolskie  1 363 658 zł
# 20          Bieńczyce       Kraków         małopolskie    599 000 zł
#
#    price_per_m2_text rooms_count_text
# 0       11 410 zł/m²                3
# 1       13 240 zł/m²                3
# 2       12 422 zł/m²                3
# 3       41 250 zł/m²                3
# 4       10 711 zł/m²                2
# 5       20 754 zł/m²                3
# 6       13 551 zł/m²                2
# 7       10 159 zł/m²                6
# 8       14 088 zł/m²                3
# 9       14 519 zł/m²                2
# 10      13 700 zł/m²                4
# 11      19 654 zł/m²                2
# 12      14 000 zł/m²                2
# 13      17 021 zł/m²                7
# 14      13 496 zł/m²                2
# 15      14 234 zł/m²                3
# 16      16 747 zł/m²                4
# 17      14 447 zł/m²                2
# 18      13 615 zł/m²                4
# 19      16 300 zł/m²                5
# 20      11 410 zł/m²                3
