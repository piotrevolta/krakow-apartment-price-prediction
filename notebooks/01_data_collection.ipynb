# %% [markdown]
# <a href="https://colab.research.google.com/github/piotrevolta/krakow-apartment-price-prediction/blob/main/notebooks/01_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Collection – Apartment Prices in Kraków
#
# ## Goal
# The goal of this notebook is to collect raw apartment listing data
# that will be used in further stages of the data science project.
#
# At this stage:
# - no data cleaning is performed
# - no analysis is done
# - data is saved in raw form

# %% [markdown]
# ## Data source
# Planned data source:
# - Otodom.pl (public real estate listings)
#
# Important notes:
# - Data collection is for educational purposes only
# - No personal data will be collected
# - Scraping logic will be implemented in a separate module

# %% [markdown]
# ## Data collection logic
#
# Scraping logic will be implemented in:
# - src/scraping.py
#
# This notebook will only call that logic and save results to:
# - data/raw/

# %%
import pandas as pd

# %%
#Repository creation on Colab based on GitHub

from pathlib import Path

# %cd /content

REPO_URL = "https://github.com/piotrevolta/krakow-apartment-price-prediction.git"
REPO_DIR = Path("/content/krakow-apartment-price-prediction")

if not REPO_DIR.exists():
    # !git clone {REPO_URL}

# %cd /content/krakow-apartment-price-prediction
# !pwd
# !ls
# Out:
# /content
# Cloning into 'krakow-apartment-price-prediction'...
# remote: Enumerating objects: 158, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 158 (delta 67), reused 64 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (158/158), 55.58 KiB | 2.06 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# /content/krakow-apartment-price-prediction
# /content/krakow-apartment-price-prediction
#  data			   notebooks   reports		  src
# 'Fields description.txt'   README.md   requirements.txt

# %%
#repository synchronization GitHub -> Colab
#!git pull --rebase

import importlib
import src.scraping as sc

importlib.reload(sc)
from src.scraping import collect_raw_listings

print("Imported from:", sc.__file__)
# Out:
# Imported from: /content/krakow-apartment-price-prediction/src/scraping.py

# %%
df_raw = collect_raw_listings(max_pages=1)
df_enriched = enrich_with_details(df_raw, max_details=10)

print("df_raw shape:", df_raw.shape)
print("df_enriched shape:", df_enriched.shape)

out_dir = Path("data/raw")
out_dir.mkdir(parents=True, exist_ok=True)

out_path = out_dir / "apartments_krakow_enriched.csv"
df_enriched.to_csv(out_path, index=False)

print("Saved:", out_path.resolve())
print("Files in data/raw:", [p.name for p in out_dir.glob("*")])
# Out:
# df_raw shape: (19, 9)
# Saved: /content/krakow-apartment-price-prediction/data/raw/apartments_krakow_raw.csv
# Files in data/raw: ['apartments_krakow_raw.csv', '.gitkeep']

# %%
df_raw.head(50)
# Out:
#                                           listing_url  \
# 0   https://www.otodom.pl/pl/oferta/bronowice-wyja...
# 1   https://www.otodom.pl/pl/oferta/bronowice-apar...
# 2   https://www.otodom.pl/pl/oferta/ruczaj-3-pokoj...
# 3   https://www.otodom.pl/pl/oferta/ruczaj-2-pokoj...
# 4   https://www.otodom.pl/pl/oferta/czyzyny-2-poko...
# 5   https://www.otodom.pl/pl/oferta/4-pokoje-pradn...
# 6   https://www.otodom.pl/pl/oferta/3-pokoje-pradn...
# 7   https://www.otodom.pl/pl/oferta/inwestycja-3-p...
# 8   https://www.otodom.pl/pl/oferta/dochodowa-inwe...
# 9   https://www.otodom.pl/pl/oferta/nowa-inwestycj...
# 10  https://www.otodom.pl/pl/oferta/nowa-inwestycj...
# 11  https://www.otodom.pl/pl/oferta/2pok-mieszkani...
# 12  https://www.otodom.pl/pl/oferta/nowa-inwestycj...
# 13  https://www.otodom.pl/pl/oferta/3-pokojowe-mie...
# 14  https://www.otodom.pl/pl/oferta/nowa-inwestycj...
# 15  https://www.otodom.pl/pl/oferta/nowa-inwestycj...
# 16  https://www.otodom.pl/pl/oferta/funkcjonalne-m...
# 17  https://www.otodom.pl/pl/oferta/3-pokoje-z-duz...
# 18  https://www.otodom.pl/pl/oferta/4-pokojowe-mie...
#
#                                          address_text        address_street  \
# 0   ul. Odlewnicza, Małe Błonia, Krowodrza, Kraków...        ul. Odlewnicza
# 1   ul. Odlewnicza, Małe Błonia, Krowodrza, Kraków...        ul. Odlewnicza
# 2   ul. Lubostroń, Ruczaj, Dębniki, Kraków, małopo...         ul. Lubostroń
# 3   ul. Karola Bunscha, Płaszów, Podgórze, Kraków,...    ul. Karola Bunscha
# 4   ul. Śliwkowa, Czyżyny, Czyżyny, Kraków, małopo...          ul. Śliwkowa
# 5   ul. Piaszczysta, Prądnik Biały Zachód, Prądnik...       ul. Piaszczysta
# 6   ul. Piaszczysta, Prądnik Biały Zachód, Prądnik...       ul. Piaszczysta
# 7   ul. Ugorek, Rakowice, Prądnik Czerwony, Kraków...            ul. Ugorek
# 8   ul. Wojciecha Weissa, Azory, Prądnik Biały, Kr...  ul. Wojciecha Weissa
# 9   ul. Mogilska, Grzegórzki Północ, Grzegórzki, K...          ul. Mogilska
# 10  ul. Mogilska, Grzegórzki Północ, Grzegórzki, K...          ul. Mogilska
# 11               Ruczaj, Dębniki, Kraków, małopolskie                  None
# 12  ul. Mogilska, Grzegórzki Północ, Grzegórzki, K...          ul. Mogilska
# 13  ul. Przewóz, Płaszów, Podgórze, Kraków, małopo...           ul. Przewóz
# 14  ul. Mogilska, Grzegórzki Północ, Grzegórzki, K...          ul. Mogilska
# 15  ul. Mogilska, Grzegórzki Północ, Grzegórzki, K...          ul. Mogilska
# 16  ul. Włoska, Wola Duchacka, Podgórze Duchackie,...            ul. Włoska
# 17  ul. Sosnowiecka, Bronowice Wielkie, Prądnik Bi...       ul. Sosnowiecka
# 18  ul. Stefana Banacha, Górka Narodowa, Prądnik B...   ul. Stefana Banacha
#
#      address_subdistrict    address_district address_city address_voivodeship  \
# 0            Małe Błonia           Krowodrza       Kraków         małopolskie
# 1            Małe Błonia           Krowodrza       Kraków         małopolskie
# 2                 Ruczaj             Dębniki       Kraków         małopolskie
# 3                Płaszów            Podgórze       Kraków         małopolskie
# 4                Czyżyny             Czyżyny       Kraków         małopolskie
# 5   Prądnik Biały Zachód       Prądnik Biały       Kraków         małopolskie
# 6   Prądnik Biały Zachód       Prądnik Biały       Kraków         małopolskie
# 7               Rakowice    Prądnik Czerwony       Kraków         małopolskie
# 8                  Azory       Prądnik Biały       Kraków         małopolskie
# 9      Grzegórzki Północ          Grzegórzki       Kraków         małopolskie
# 10     Grzegórzki Północ          Grzegórzki       Kraków         małopolskie
# 11                Ruczaj             Dębniki       Kraków         małopolskie
# 12     Grzegórzki Północ          Grzegórzki       Kraków         małopolskie
# 13               Płaszów            Podgórze       Kraków         małopolskie
# 14     Grzegórzki Północ          Grzegórzki       Kraków         małopolskie
# 15     Grzegórzki Północ          Grzegórzki       Kraków         małopolskie
# 16         Wola Duchacka  Podgórze Duchackie       Kraków         małopolskie
# 17     Bronowice Wielkie       Prądnik Biały       Kraków         małopolskie
# 18        Górka Narodowa       Prądnik Biały       Kraków         małopolskie
#
#        price_text price_per_m2_text
# 0    1 224 960 zł      22 004 zł/m²
# 1    2 310 630 zł      21 000 zł/m²
# 2    1 200 000 zł      17 956 zł/m²
# 3   698 006,71 zł      13 434 zł/m²
# 4      605 100 zł      18 198 zł/m²
# 5    1 756 350 zł      15 000 zł/m²
# 6      912 608 zł      15 200 zł/m²
# 7      749 000 zł      13 187 zł/m²
# 8    1 090 000 zł      15 430 zł/m²
# 9   760 469,05 zł      18 810 zł/m²
# 10     679 200 zł      20 000 zł/m²
# 11     540 000 zł      13 878 zł/m²
# 12  751 996,19 zł      20 762 zł/m²
# 13     912 299 zł      12 911 zł/m²
# 14  813 432,38 zł      21 095 zł/m²
# 15     854 320 zł      19 667 zł/m²
# 16     695 000 zł      15 438 zł/m²
# 17     948 000 zł      17 720 zł/m²
# 18     950 253 zł      13 176 zł/m²
