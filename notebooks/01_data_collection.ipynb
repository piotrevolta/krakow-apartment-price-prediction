# %% [markdown]
# <a href="https://colab.research.google.com/github/piotrevolta/krakow-apartment-price-prediction/blob/main/notebooks/01_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Collection – Apartment Prices in Kraków
#
# ## Goal
# The goal of this notebook is to collect raw apartment listing data
# that will be used in further stages of the data science project.
#
# At this stage:
# - no data cleaning is performed
# - no analysis is done
# - data is saved in raw form

# %% [markdown]
# ## Data source
# Planned data source:
# - Otodom.pl (public real estate listings)
#
# Important notes:
# - Data collection is for educational purposes only
# - No personal data will be collected
# - Scraping logic will be implemented in a separate module

# %% [markdown]
# ## Data collection logic
#
# Scraping logic will be implemented in:
# - src/scraping.py
#
# This notebook will only call that logic and save results to:
# - data/raw/

# %%
import pandas as pd

# %%
#Repository creation on Colab based on GitHub

from pathlib import Path

# %cd /content

REPO_URL = "https://github.com/piotrevolta/krakow-apartment-price-prediction.git"
REPO_DIR = Path("/content/krakow-apartment-price-prediction")

if not REPO_DIR.exists():
    # !git clone {REPO_URL}

# %cd /content/krakow-apartment-price-prediction
# !pwd
# !ls
# Out:
# /content
# /content/krakow-apartment-price-prediction
# /content/krakow-apartment-price-prediction
# data  notebooks  README.md  reports  requirements.txt  src

# %%
#repository synchronization GitHub -> Colab
# !git pull --rebase

import importlib
import src.scraping as sc

importlib.reload(sc)
from src.scraping import collect_raw_listings

print("Imported from:", sc.__file__)
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 564 bytes | 564.00 KiB/s, done.
# From https://github.com/piotrevolta/krakow-apartment-price-prediction
#    aaf0754..7964719  main       -> origin/main
# Successfully rebased and updated refs/heads/main.
# Imported from: /content/krakow-apartment-price-prediction/src/scraping.py

# %%
df_raw = collect_raw_listings()
print("df_raw shape:", df_raw.shape)

out_dir = Path("data/raw")
out_dir.mkdir(parents=True, exist_ok=True)

out_path = out_dir / "apartments_krakow_raw.csv"
df_raw.to_csv(out_path, index=False)

print("Saved:", out_path.resolve())
print("Files in data/raw:", [p.name for p in out_dir.glob("*")])
# Out:
# df_raw shape: (45, 6)
# Saved: /content/krakow-apartment-price-prediction/data/raw/apartments_krakow_raw.csv
# Files in data/raw: ['apartments_krakow_raw.csv', '.gitkeep', '.ipynb_checkpoints']
#                                                title  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  Nowe| Wykończone pod klucz - standard 6000 pln/m2
#
#                                                price  area_m2 rooms  \
# 0                                               None      NaN  None
# 1                                               None      NaN  None
# 2                                               None      NaN  None
# 3                                               None      NaN  None
# 4  {'value': 829000, 'currency': 'PLN', '__typena...    39.41  None
#
#                                                  url  source
# 0                                                  /  otodom
# 1         /pl/wyniki/sprzedaz/mieszkanie/cala-polska  otodom
# 2         /pl/wyniki/sprzedaz/mieszkanie/malopolskie  otodom
# 3  /pl/wyniki/sprzedaz/mieszkanie/malopolskie/kra...  otodom
# 4  [lang]/ad/nowe-wykonczone-pod-klucz-standard-6...  otodom

# %%
df_raw.head(50)
# Out:
#                                                 title  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4   Nowe| Wykończone pod klucz - standard 6000 pln/m2
# 5                                          Essa Kliny
# 6                 4-pokojowe mieszkanie 88m2 + balkon
# 8    3-pokojowe mieszkanie 56m2 + balkon Bezpośrednio
# 10   4-pokojowe mieszkanie 74m2 + balkon Bezpośrednio
# 12   3-pokojowe mieszkanie 56m2 + balkon Bez Prowizji
# 14                1-pokojowe mieszkanie 32m2 + balkon
# 16               2-pokojowe mieszkanie 48m2 + ogródek
# 18                1-pokojowe mieszkanie 32m2 + balkon
# 20  2-pokojowe mieszkanie 43m2 + ogródek Bezpośrednio
# 22   3-pokojowe mieszkanie 63m2 + loggia Bezpośrednio
# 25   4-pokojowe mieszkanie 68m2 + loggia Bezpośrednio
# 27   3-pokojowe mieszkanie 66m2 + balkon Bez Prowizji
# 29   2-pokojowe mieszkanie 40m2 + balkon Bez Prowizji
# 32         4-pokojowe mieszkanie 73m2 Bez Pośredników
# 34         5-pokojowe mieszkanie 92m2 Bez Pośredników
# 37  3-pokojowe mieszkanie 59m2 + ogródek Bez Prowizji
# 39                2-pokojowe mieszkanie 55m2 + balkon
# 41   3-pokojowe mieszkanie 54m2 + balkon Bezpośrednio
# 43                2-pokojowe mieszkanie 55m2 + balkon
# 46                4-pokojowe mieszkanie 73m2 + balkon
# 48   3-pokojowe mieszkanie 58m2 + balkon Bezpośrednio
# 50                2-pokojowe mieszkanie 40m2 + balkon
# 52   1-pokojowe mieszkanie 37m2 + balkon Bezpośrednio
# 55  Kuźnicy Kołłątajowskiej 42 | mieszkanie 4-pok....
# 57  Kuźnicy Kołłątajowskiej 42 | mieszkanie 3-pok.| 3
# 59  Kuźnicy Kołłątajowskiej 42 | mieszkanie 2-pok....
# 62   3-pokojowe mieszkanie 57m2 + balkon Bezpośrednio
# 64   4-pokojowe mieszkanie 70m2 + balkon Bez Prowizji
# 66   1-pokojowe mieszkanie 25m2 + balkon Bez Prowizji
# 68    2-pokojowe mieszkanie 43m2 + taras Bezpośrednio
# 71                4-pokojowe mieszkanie 55m2 + balkon
# 73   2-pokojowe mieszkanie 37m2 + balkon Bez Prowizji
# 75                3-pokojowe mieszkanie 48m2 + balkon
# 77            1-pokojowe mieszkanie 25m2 Bezpośrednio
# 79   1-pokojowe mieszkanie 29m2 + loggia Bezpośrednio
# 81  ul.  Seweryna / Kraków | Przestronne mieszkani...
# 82  Nowe| Wykończone pod klucz - standard 6000 pln/m2
# 83                                               None
# 84                                               None
# 85                                               None
#
#                                                 price  area_m2 rooms  \
# 0                                                None      NaN  None
# 1                                                None      NaN  None
# 2                                                None      NaN  None
# 3                                                None      NaN  None
# 4   {'value': 829000, 'currency': 'PLN', '__typena...    39.41  None
# 5                                                None      NaN  None
# 6   {'value': 1145300, 'currency': 'PLN', '__typen...    88.10  None
# 8   {'value': 673183, 'currency': 'PLN', '__typena...    56.57  None
# 10  {'value': 877383, 'currency': 'PLN', '__typena...    74.99  None
# 12  {'value': 683287, 'currency': 'PLN', '__typena...    56.47  None
# 14  {'value': 482332, 'currency': 'PLN', '__typena...    32.59  None
# 16  {'value': 624650, 'currency': 'PLN', '__typena...    48.05  None
# 18  {'value': 483952, 'currency': 'PLN', '__typena...    32.48  None
# 20  {'value': 576821, 'currency': 'PLN', '__typena...    43.37  None
# 22  {'value': 947044, 'currency': 'PLN', '__typena...    63.56  None
# 25  {'value': 984062, 'currency': 'PLN', '__typena...    68.18  None
# 27  {'value': 976740, 'currency': 'PLN', '__typena...    66.90  None
# 29  {'value': 722265, 'currency': 'PLN', '__typena...    40.35  None
# 32  {'value': 1092684, 'currency': 'PLN', '__typen...    73.84  None
# 34  {'value': 1346905, 'currency': 'PLN', '__typen...    92.90  None
# 37  {'value': 861300, 'currency': 'PLN', '__typena...    59.40  None
# 39  {'value': 835634, 'currency': 'PLN', '__typena...    55.34  None
# 41  {'value': 849710, 'currency': 'PLN', '__typena...    54.82  None
# 43  {'value': 829350, 'currency': 'PLN', '__typena...    55.29  None
# 46  {'value': 1100700, 'currency': 'PLN', '__typen...    73.38  None
# 48  {'value': 907680, 'currency': 'PLN', '__typena...    58.56  None
# 50  {'value': 686290, 'currency': 'PLN', '__typena...    40.37  None
# 52  {'value': 664650, 'currency': 'PLN', '__typena...    37.98  None
# 55  {'value': 968760, 'currency': 'PLN', '__typena...    71.76  None
# 57  {'value': 921128, 'currency': 'PLN', '__typena...    67.73  None
# 59  {'value': 682440, 'currency': 'PLN', '__typena...    48.40  None
# 62  {'value': 716308, 'currency': 'PLN', '__typena...    57.14  None
# 64  {'value': 861677, 'currency': 'PLN', '__typena...    70.87  None
# 66  {'value': 379577, 'currency': 'PLN', '__typena...    25.52  None
# 68  {'value': 642293, 'currency': 'PLN', '__typena...    43.39  None
# 71  {'value': 996493, 'currency': 'PLN', '__typena...    55.67  None
# 73  {'value': 678633, 'currency': 'PLN', '__typena...    37.66  None
# 75  {'value': 858138, 'currency': 'PLN', '__typena...    48.21  None
# 77  {'value': 456332, 'currency': 'PLN', '__typena...    25.38  None
# 79  {'value': 487874, 'currency': 'PLN', '__typena...    29.39  None
# 81  {'value': 675000, 'currency': 'PLN', '__typena...    46.00  None
# 82  {'value': 829000, 'currency': 'PLN', '__typena...    39.41  None
# 83                                               None      NaN  None
# 84                                               None      NaN  None
# 85                                               None      NaN  None
#
#                                                   url  source
# 0                                                   /  otodom
# 1          /pl/wyniki/sprzedaz/mieszkanie/cala-polska  otodom
# 2          /pl/wyniki/sprzedaz/mieszkanie/malopolskie  otodom
# 3   /pl/wyniki/sprzedaz/mieszkanie/malopolskie/kra...  otodom
# 4   [lang]/ad/nowe-wykonczone-pod-klucz-standard-6...  otodom
# 5                                                None  otodom
# 6   [lang]/ad/4-pokojowe-mieszkanie-88m2-balkon-ID...  otodom
# 8   [lang]/ad/3-pokojowe-mieszkanie-56m2-balkon-be...  otodom
# 10  [lang]/ad/4-pokojowe-mieszkanie-74m2-balkon-be...  otodom
# 12  [lang]/ad/3-pokojowe-mieszkanie-56m2-balkon-be...  otodom
# 14  [lang]/ad/1-pokojowe-mieszkanie-32m2-balkon-ID...  otodom
# 16  [lang]/ad/2-pokojowe-mieszkanie-48m2-ogrodek-I...  otodom
# 18  [lang]/ad/1-pokojowe-mieszkanie-32m2-balkon-ID...  otodom
# 20  [lang]/ad/2-pokojowe-mieszkanie-43m2-ogrodek-b...  otodom
# 22  [lang]/ad/3-pokojowe-mieszkanie-63m2-loggia-be...  otodom
# 25  [lang]/ad/4-pokojowe-mieszkanie-68m2-loggia-be...  otodom
# 27  [lang]/ad/3-pokojowe-mieszkanie-66m2-balkon-be...  otodom
# 29  [lang]/ad/2-pokojowe-mieszkanie-40m2-balkon-be...  otodom
# 32  [lang]/ad/4-pokojowe-mieszkanie-73m2-bez-posre...  otodom
# 34  [lang]/ad/5-pokojowe-mieszkanie-92m2-bez-posre...  otodom
# 37  [lang]/ad/3-pokojowe-mieszkanie-59m2-ogrodek-b...  otodom
# 39  [lang]/ad/2-pokojowe-mieszkanie-55m2-balkon-ID...  otodom
# 41  [lang]/ad/3-pokojowe-mieszkanie-54m2-balkon-be...  otodom
# 43  [lang]/ad/2-pokojowe-mieszkanie-55m2-balkon-ID...  otodom
# 46  [lang]/ad/4-pokojowe-mieszkanie-73m2-balkon-ID...  otodom
# 48  [lang]/ad/3-pokojowe-mieszkanie-58m2-balkon-be...  otodom
# 50  [lang]/ad/2-pokojowe-mieszkanie-40m2-balkon-ID...  otodom
# 52  [lang]/ad/1-pokojowe-mieszkanie-37m2-balkon-be...  otodom
# 55  [lang]/ad/kuznicy-kollatajowskiej-42-mieszkani...  otodom
# 57  [lang]/ad/kuznicy-kollatajowskiej-42-mieszkani...  otodom
# 59  [lang]/ad/kuznicy-kollatajowskiej-42-mieszkani...  otodom
# 62  [lang]/ad/3-pokojowe-mieszkanie-57m2-balkon-be...  otodom
# 64  [lang]/ad/4-pokojowe-mieszkanie-70m2-balkon-be...  otodom
# 66  [lang]/ad/1-pokojowe-mieszkanie-25m2-balkon-be...  otodom
# 68  [lang]/ad/2-pokojowe-mieszkanie-43m2-taras-bez...  otodom
# 71  [lang]/ad/4-pokojowe-mieszkanie-55m2-balkon-ID...  otodom
# 73  [lang]/ad/2-pokojowe-mieszkanie-37m2-balkon-be...  otodom
# 75  [lang]/ad/3-pokojowe-mieszkanie-48m2-balkon-ID...  otodom
# 77  [lang]/ad/1-pokojowe-mieszkanie-25m2-bezposred...  otodom
# 79  [lang]/ad/1-pokojowe-mieszkanie-29m2-loggia-be...  otodom
# 81  [lang]/ad/ul-seweryna-krakow-przestronne-miesz...  otodom
# 82  hpr/[lang]/ad/nowe-wykonczone-pod-klucz-standa...  otodom
# 83  https://maps.googleapis.com/maps/api/staticmap...  otodom
# 84  https://maps.googleapis.com/maps/api/staticmap...  otodom
# 85  https://maps.googleapis.com/maps/api/staticmap...  otodom
