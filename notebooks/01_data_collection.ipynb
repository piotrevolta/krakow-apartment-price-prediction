# %% [markdown]
# # Data Collection – Apartment Prices in Kraków
#
# ## Goal
# The goal of this notebook is to collect raw apartment listing data
# that will be used in further stages of the data science project.
#
# At this stage:
# - no data cleaning is performed
# - no analysis is done
# - data is saved in raw form

# %% [markdown]
# ## Data source
# Planned data source:
# - Otodom.pl (public real estate listings)
#
# Important notes:
# - Data collection is for educational purposes only
# - No personal data will be collected
# - Scraping logic will be implemented in a separate module

# %% [markdown]
# ## Data collection logic
#
# Scraping logic will be implemented in:
# - src/scraping.py
#
# This notebook will only call that logic and save results to:
# - data/raw/

# %%
import pandas as pd

# %%
#Repository creation on Colab based on GitHub

from pathlib import Path

# %cd /content

REPO_URL = "https://github.com/piotrevolta/krakow-apartment-price-prediction.git"
REPO_DIR = Path("/content/krakow-apartment-price-prediction")

if not REPO_DIR.exists():
    # !git clone {REPO_URL}

# %cd /content/krakow-apartment-price-prediction
# !pwd
# !ls
# Out:
# /content
# /content/krakow-apartment-price-prediction
# /content/krakow-apartment-price-prediction
#  data			   notebooks   reports		  src
# 'Fields description.txt'   README.md   requirements.txt

# %%
#repository synchronization GitHub -> Colab
#!git pull --rebase

import importlib
import src.scraping as sc

importlib.reload(sc)
from src.scraping import collect_raw_listings, enrich_with_details

print("Imported from:", sc.__file__)
# Out:
# Imported from: /content/krakow-apartment-price-prediction/src/scraping.py

# %%
df_raw = collect_raw_listings(max_pages=1)
df_enriched = enrich_with_details(df_raw, max_details=30, sleep_s=1.0)

print("df_raw shape:", df_raw.shape)
print("df_enriched shape:", df_enriched.shape)

out_dir = Path("data/raw")
out_dir.mkdir(parents=True, exist_ok=True)

out_path = out_dir / "apartments_krakow_enriched.csv"
df_enriched.to_csv(out_path, index=False)

print("Saved:", out_path.resolve())
print("Files in data/raw:", [p.name for p in out_dir.glob("*")])
# Out:
# df_raw shape: (24, 9)
# df_enriched shape: (24, 15)
# Saved: /content/krakow-apartment-price-prediction/data/raw/apartments_krakow_enriched.csv
# Files in data/raw: ['apartments_krakow_raw.csv', '.gitkeep', 'apartments_krakow_enriched.csv']

# %%
df_enriched.head(50)
# Out:
#                                           listing_url  \
# 0   https://www.otodom.pl/pl/oferta/przestronne-i-...
# 1   https://www.otodom.pl/pl/oferta/wykonczony-pod...
# 2   https://www.otodom.pl/pl/oferta/2-pokojowe-mie...
# 3   https://www.otodom.pl/pl/oferta/apartament-z-o...
# 4   https://www.otodom.pl/pl/oferta/bezposrednio-3...
# 5   https://www.otodom.pl/pl/oferta/3-pokojowe-mie...
# 6   https://www.otodom.pl/pl/oferta/jasne-3niezale...
# 7   https://www.otodom.pl/pl/oferta/3-pokojowe-mie...
# 8   https://www.otodom.pl/pl/oferta/2-pokoje-remon...
# 9   https://www.otodom.pl/pl/oferta/ekskluzywna-ni...
# 10  https://www.otodom.pl/pl/oferta/wola-justowska...
# 11  https://www.otodom.pl/pl/oferta/dwupoziomowy-a...
# 12  https://www.otodom.pl/pl/oferta/unikatowy-tara...
# 13  https://www.otodom.pl/pl/oferta/mieszkanie-2-p...
# 14  https://www.otodom.pl/pl/oferta/4-pokojowe-mie...
# 15  https://www.otodom.pl/pl/oferta/pilna-sprzedaz...
# 16  https://www.otodom.pl/pl/oferta/2-pokojowe-spr...
# 17  https://www.otodom.pl/pl/oferta/gotowiec-inwes...
# 18  https://www.otodom.pl/pl/oferta/ladne-2-pokojo...
# 19  https://www.otodom.pl/pl/oferta/pradnik-czerwo...
# 20  https://www.otodom.pl/pl/oferta/plaszow-mysliw...
# 21  https://www.otodom.pl/pl/oferta/krowodrza-ulic...
# 22  https://www.otodom.pl/pl/oferta/3-pokojowe-mie...
# 23  https://www.otodom.pl/hpr/pl/oferta/przestronn...
#
#                                          address_text  \
# 0      Bronowice Małe, Bronowice, Kraków, małopolskie
# 1   Nowy Bieżanów, Bieżanów-Prokocim, Kraków, mało...
# 2   ul. Pękowicka 96, Tonie, Prądnik Biały, Kraków...
# 3   ul. Stanisława Przybyszewskiego, Małe Błonia, ...
# 4   os. Na Lotnisku, Nowe Bieńczyce, Bieńczyce, Kr...
# 5   ul. Josepha Conrada, Azory Zachód, Prądnik Bia...
# 6   ul. Kobierzyńska, Ruczaj, Dębniki, Kraków, mał...
# 7   ul. Dajwór, Kazimierz, Stare Miasto, Kraków, m...
# 8     Stare Bieńczyce, Bieńczyce, Kraków, małopolskie
# 9   ul. Piaskowa, Bronowice Wielkie, Prądnik Biały...
# 10  ul. Królowej Jadwigi, Wola Justowska, Zwierzyn...
# 11  ul. Władysława Łokietka, Tonie, Prądnik Biały,...
# 12  ul. Górka Narodowa, Górka Narodowa, Prądnik Bi...
# 13  os. Dywizjonu 303 303, Czyżyny Lotnisko, Czyży...
# 14  Federowicza, Skotniki, Dębniki, Kraków, małopo...
# 15  ul. bp. Jana Prandoty, Przedmieście Warszawski...
# 16  ul. Rakowicka, Osiedle Oficerskie, Grzegórzki,...
# 17  ul. Siewna, Prądnik Biały Wschód, Prądnik Biał...
# 18  ul. Złocieniowa, Złocień, Bieżanów-Prokocim, K...
# 19  ul. abp. Zygmunta Szczęsnego Felińskiego, Prąd...
# 20  ul. Myśliwska, Płaszów, Podgórze, Kraków, mało...
# 21  ul. Marii Jaremy, Nowa Wieś, Krowodrza, Kraków...
# 22  Wizjonerów, Bronowice Małe, Bronowice, Kraków,...
# 23     Bronowice Małe, Bronowice, Kraków, małopolskie
#
#                               address_street       address_subdistrict  \
# 0                                       None            Bronowice Małe
# 1                                       None             Nowy Bieżanów
# 2                           ul. Pękowicka 96                     Tonie
# 3            ul. Stanisława Przybyszewskiego               Małe Błonia
# 4                            os. Na Lotnisku            Nowe Bieńczyce
# 5                        ul. Josepha Conrada              Azory Zachód
# 6                           ul. Kobierzyńska                    Ruczaj
# 7                                 ul. Dajwór                 Kazimierz
# 8                                       None           Stare Bieńczyce
# 9                               ul. Piaskowa         Bronowice Wielkie
# 10                      ul. Królowej Jadwigi            Wola Justowska
# 11                   ul. Władysława Łokietka                     Tonie
# 12                        ul. Górka Narodowa            Górka Narodowa
# 13                     os. Dywizjonu 303 303          Czyżyny Lotnisko
# 14                               Federowicza                  Skotniki
# 15                     ul. bp. Jana Prandoty  Przedmieście Warszawskie
# 16                             ul. Rakowicka        Osiedle Oficerskie
# 17                                ul. Siewna      Prądnik Biały Wschód
# 18                           ul. Złocieniowa                   Złocień
# 19  ul. abp. Zygmunta Szczęsnego Felińskiego          Prądnik Czerwony
# 20                             ul. Myśliwska                   Płaszów
# 21                          ul. Marii Jaremy                 Nowa Wieś
# 22                                Wizjonerów            Bronowice Małe
# 23                                      None            Bronowice Małe
#
#      address_district address_city address_voivodeship    price_text  \
# 0           Bronowice       Kraków         małopolskie    840 000 zł
# 1   Bieżanów-Prokocim       Kraków         małopolskie    991 066 zł
# 2       Prądnik Biały       Kraków         małopolskie    720 250 zł
# 3           Krowodrza       Kraków         małopolskie  1 020 000 zł
# 4           Bieńczyce       Kraków         małopolskie    599 000 zł
# 5       Prądnik Biały       Kraków         małopolskie    901 511 zł
# 6             Dębniki       Kraków         małopolskie    795 000 zł
# 7        Stare Miasto       Kraków         małopolskie  2 875 537 zł
# 8           Bieńczyce       Kraków         małopolskie    399 000 zł
# 9       Prądnik Biały       Kraków         małopolskie  1 349 000 zł
# 10        Zwierzyniec       Kraków         małopolskie    725 000 zł
# 11      Prądnik Biały       Kraków         małopolskie  1 600 000 zł
# 12      Prądnik Biały       Kraków         małopolskie    765 000 zł
# 13            Czyżyny       Kraków         małopolskie    739 000 zł
# 14            Dębniki       Kraków         małopolskie  1 008 320 zł
# 15       Stare Miasto       Kraków         małopolskie    756 666 zł
# 16         Grzegórzki       Kraków         małopolskie    359 800 zł
# 17      Prądnik Biały       Kraków         małopolskie  1 200 000 zł
# 18  Bieżanów-Prokocim       Kraków         małopolskie    659 000 zł
# 19   Prądnik Czerwony       Kraków         małopolskie    669 000 zł
# 20           Podgórze       Kraków         małopolskie  1 390 000 zł
# 21          Krowodrza       Kraków         małopolskie    549 000 zł
# 22          Bronowice       Kraków         małopolskie    950 000 zł
# 23          Bronowice       Kraków         małopolskie    840 000 zł
#
#    price_per_m2_text floor_text rooms_count_text  has_garden  has_balcony  \
# 0       16 522 zł/m²        3/3                2           0            1
# 1       10 300 zł/m²     parter                5           1            0
# 2       12 500 zł/m²        2/2                2           0            0
# 3       22 083 zł/m²     parter                2           1            0
# 4       11 410 zł/m²       4/10                3           0            1
# 5       13 240 zł/m²        3/5                3           0            1
# 6       12 422 zł/m²        3/3                3           0            1
# 7       41 250 zł/m²        3/3                3           0            0
# 8       10 711 zł/m²        4/4                2           0            0
# 9       20 754 zł/m²   parter/1                3           1            0
# 10      13 551 zł/m²        2/3                2           0            1
# 11      10 159 zł/m²     parter                6           1            0
# 12      14 088 zł/m²        1/4                3           0            1
# 13      14 519 zł/m²       7/10                2           0            1
# 14      13 700 zł/m²        2/3                4           0            0
# 15      19 654 zł/m²  parter/10                2           1            1
# 16      14 000 zł/m²        2/4                2           0            1
# 17      17 021 zł/m²   parter/4                7           0            1
# 18      13 496 zł/m²        1/3                2           0            1
# 19      14 234 zł/m²        4/4                3           0            1
# 20      16 747 zł/m²        3/3                4           0            1
# 21      14 447 zł/m²   parter/4                2           0            0
# 22      15 200 zł/m²        2/3                3           0            1
# 23      16 522 zł/m²        3/3                2           0            1
#
#     has_parking  has_basement
# 0             1             0
# 1             1             0
# 2             1             0
# 3             0             0
# 4             0             1
# 5             1             0
# 6             0             1
# 7             1             0
# 8             0             1
# 9             1             0
# 10            1             0
# 11            1             0
# 12            1             1
# 13            0             1
# 14            1             0
# 15            1             1
# 16            0             0
# 17            0             1
# 18            0             0
# 19            0             0
# 20            1             0
# 21            0             1
# 22            1             0
# 23            1             0
