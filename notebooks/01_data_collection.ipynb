# %% [markdown]
# <a href="https://colab.research.google.com/github/piotrevolta/krakow-apartment-price-prediction/blob/main/notebooks/01_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Collection – Apartment Prices in Kraków
#
# ## Goal
# The goal of this notebook is to collect raw apartment listing data
# that will be used in further stages of the data science project.
#
# At this stage:
# - no data cleaning is performed
# - no analysis is done
# - data is saved in raw form

# %% [markdown]
# ## Data source
# Planned data source:
# - Otodom.pl (public real estate listings)
#
# Important notes:
# - Data collection is for educational purposes only
# - No personal data will be collected
# - Scraping logic will be implemented in a separate module

# %%
import pandas as pd

# %%
# !git clone https://github.com/piotrevolta/krakow-apartment-price-prediction.git
# %cd krakow-apartment-price-prediction
# !ls
# Out:
# fatal: destination path 'krakow-apartment-price-prediction' already exists and is not an empty directory.
# /content/krakow-apartment-price-prediction/krakow-apartment-price-prediction
# data				   notebooks  reports		src
# krakow-apartment-price-prediction  README.md  requirements.txt

# %%
import sys
from pathlib import Path

project_root = Path.cwd()
sys.path.insert(0, str(project_root))
print("Project root:", project_root)
# Out:
# Project root: /content/krakow-apartment-price-prediction/krakow-apartment-price-prediction

# %%
import importlib
import src.scraping

importlib.reload(src.scraping)

from src.scraping import collect_raw_listings

# %%
from src.scraping import collect_raw_listings
print("Import OK")
# Out:
# Import OK

# %%
try:
    df_raw = collect_raw_listings()

    from pathlib import Path

    Path("data/raw").mkdir(parents=True, exist_ok=True)

    out_path = "data/raw/apartments_krakow_raw.csv"
    df_raw.to_csv(out_path, index=False)

    print("Saved:", out_path)
    df_raw.head()

except NotImplementedError as e:
    print("Scraping not implemented yet:")
    print(e)
# Out:
# Scraping not implemented yet:
# Scraping logic not implemented yet

# %% [markdown]
# ## Data collection logic
#
# Scraping logic will be implemented in:
# - src/scraping.py
#
# This notebook will only call that logic and save results to:
# - data/raw/

# %%
# Placeholder – scraping not implemented yet
# Example:
# df_raw = collect_data()
# df_raw.to_csv("data/raw/apartments.csv", index=False)

print("Data collection step – not implemented yet")
# Out:
# Data collection step – not implemented yet

# %%
# !git status
# !git add src/scraping.py notebooks/01_data_collection.ipynb data/raw/apartments_krakow_raw.csv
# !git commit -m "Add dummy data collection pipeline"
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	krakow-apartment-price-prediction/
#
# nothing added to commit but untracked files present (use "git add" to track)
# fatal: pathspec 'data/raw/apartments_krakow_raw.csv' did not match any files
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@08c3a4251fbf.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address
